# %%
from inference import Inference
from model import SSCDModel


print("Loading model")
model = SSCDModel.load_from_checkpoint("segmentation_bigdata.ckpt")
print("Creating inference object")
inf = Inference(model)

print("Predicting on audio")
prediction, activations = inf("audio3.wav")
print("Printing prediction")

# %%
# from pyannote.core import Segment, notebook
# make notebook visualization zoom on 600s < t < 660s time range
# EXCERPT = Segment(600, 660)
# notebook.crop = EXCERPT

# %%
prediction

# %%
activations
